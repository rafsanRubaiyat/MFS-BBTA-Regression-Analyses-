# %%
import pandas as pd

# %%
df = pd.read_csv('mfsRegData.csv')

# %%
df = df[:-1]

# %%
df
# Out:
#           Period  UrbanAgent  RuralAgent  TotalAgent  UrbanMaleAccount  \
# 0       March'22    614238.0    536975.0   1151213.0        31976559.0
# 1   February'22R    615505.0    532549.0   1148054.0        31292726.0
# 2     January'22    607988.0    527225.0   1135213.0        30584866.0
# 3    December'21    599309.0    524149.0   1123458.0        29570596.0
# 4    November'21    586463.0    520391.0   1106854.0        28772089.0
# 5     October'21    640126.0    515065.0   1155191.0        28100707.0
# 6   September'21    630932.0    511413.0   1142345.0        27364434.0
# 7      August'21    632704.0    528930.0   1161634.0        26589183.0
# 8        July'21    619183.0    523212.0   1142395.0        25875479.0
# 9        June'21    605707.0    525437.0   1131144.0        24932704.0
# 10        May'21    572387.0    514284.0   1086671.0        23224547.0
# 11      April'21    552485.0    509296.0   1061781.0        22080753.0
# ...

# %%
from sklearn.linear_model import LinearRegression

#initiate linear regression model
model = LinearRegression()

#define predictor and response variables
X, y = df[["RuralAgent", "RuralFemaleAccount"]], df.TransactionsNo

#fit regression model
model.fit(X, y)
# Out:
# LinearRegression()

# %%
r_squared = model.score(X, y)
#view R-squared value
print(r_squared)
# Out:
# 0.8521387747982679

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
df.plot(x='RuralAgent', y='TransactionsNo', style='o')
plt.title('Rural Agent vs Total MFS Transactions No')
plt.xlabel('Rural Agent')
plt.ylabel('Total Transactions No')
plt.show()
plt.savefig('agentVsTxnNo.png', dpi=1200)

# %%
from sklearn.linear_model import LinearRegression

#initiate linear regression model
model = LinearRegression()

#define predictor and response variables
X, y = df[["RuralAgent"]], df.TransactionsNo

#fit regression model
model.fit(X, y)
# Out:
# LinearRegression()

# %%
r_squared = model.score(X, y)
#view R-squared value
print(r_squared)
# Out:
# 0.8486982737150863

# %%
from sklearn.linear_model import LinearRegression

#initiate linear regression model
model = LinearRegression()

#define predictor and response variables
X, y = df[["RuralFemaleAccount"]], df.TransactionsNo

#fit regression model
model.fit(X, y)
r_squared = model.score(X, y)
#view R-squared value
print(r_squared)
# Out:
# 0.4090452401564537

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
df.plot(x='RuralFemaleAccount', y='TransactionsNo', style='o')
plt.title('Rural Female Accounts vs Total MFS Transactions No')
plt.xlabel('Rural Female Accounts')
plt.ylabel('Total Transactions No')
plt.show()
plt.savefig('femaleaccountsVsTxnNo.png', dpi=1200)

# %%
from sklearn.linear_model import LinearRegression

#initiate linear regression model
model = LinearRegression()

#define predictor and response variables
X, y = df[["RuralAgent", "RuralFemaleAccount"]], df.TransactionsAmount

#fit regression model
model.fit(X, y) 
r_squared = model.score(X, y)
#view R-squared value
print(r_squared)
# Out:
# 0.8503831558356667

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
df.plot(x='RuralAgent', y='TransactionsAmount', style='*') 
plt.title('Rural Agent vs Total MFS Transactions amount')
plt.xlabel('Rural Agent')
plt.ylabel('Total Transactions No')
plt.show()
plt.savefig('agentVsTxnNo.png', dpi=1200)

# %%
from sklearn.linear_model import LinearRegression

#initiate linear regression model
model = LinearRegression()

#define predictor and response variables
X, y = df[["RuralFemaleAccount"]], df.TransactionsAmount

#fit regression model
model.fit(X, y)
r_squared = model.score(X, y)
#view R-squared value
print(r_squared)
# Out:
# 0.3424128613339543

# %%
from sklearn.linear_model import LinearRegression

#initiate linear regression model
model = LinearRegression()

#define predictor and response variables
X, y = df[["RuralAgent"]], df.TransactionsAmount

#fit regression model
model.fit(X, y)
r_squared = model.score(X, y)
#view R-squared value
print(r_squared)
# Out:
# 0.8502068089292849

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
df.plot(x='RuralFemaleAccount', y='TransactionsAmount', style='*') 
plt.title('Rural Female Accounts vs Total MFS Transactions Amount')
plt.xlabel('Rural Female Accounts')
plt.ylabel('Total Transactions Amount')
plt.show()
plt.savefig('agentVsTxnNo.png', dpi=1200)

# %%
import numpy
import matplotlib.pyplot as plt

x = df.RuralAgent
y = df.TransactionsNo

mymodel = numpy.poly1d(numpy.polyfit(x, y, 3))
print(r2_score(y, mymodel(x)))
# Out:
# 0.8803996850450949

# %%
import numpy
import matplotlib.pyplot as plt

x = df.RuralFemaleAccount
y = df.TransactionsNo

mymodel = numpy.poly1d(numpy.polyfit(x, y, 3))
print(r2_score(y, mymodel(x)))
# Out:
# 0.46129656737298885

# %%
import numpy
import matplotlib.pyplot as plt

x = df.RuralAgent
y = df.TransactionsAmount

mymodel = numpy.poly1d(numpy.polyfit(x, y, 3))
print(r2_score(y, mymodel(x)))
# Out:
# 0.8776264999100962

# %%
import numpy
import matplotlib.pyplot as plt

x = df.RuralFemaleAccount
y = df.TransactionsAmount

mymodel = numpy.poly1d(numpy.polyfit(x, y, 3))
print(r2_score(y, mymodel(x)))
# Out:
# 0.3779647778522267

# %%
from sklearn.model_selection import train_test_split 
X, Y = df[["RuralAgent", "RuralFemaleAccount"]], df.TransactionsAmount
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=.20, random_state=0)
 
import numpy as np
def MAPE(Y_actual,Y_Predicted):
    mape = np.mean(np.abs((Y_actual - Y_Predicted)/Y_actual))*100
    return mape
 
from sklearn.linear_model import Ridge
ridge_model = Ridge(alpha=1.0)
ridge=ridge_model.fit(X_train , Y_train)
ridge_predict = ridge.predict(X_test)
Ridge_MAPE = MAPE(Y_test,ridge_predict)
print("MAPE value: ",Ridge_MAPE)
Accuracy = 100 - Ridge_MAPE
print('Accuracy of Ridge Regression: {:0.2f}%.'.format(Accuracy))
# Out:
# MAPE value:  8.160460408364873
# Accuracy of Ridge Regression: 91.84%.

# %%
pwd
# Out:
# 'C:\\Users\\09050'
